# %% [markdown]
# # Stage-A Activity Public Module — GitHub Showcase
#
# This notebook is a **display-oriented GitHub showcase** for the Stage-A activity regression model.
#
# It emphasizes the visible outputs that a reader or reviewer can inspect directly:
#
# - the 24-feature Stage-A activity design matrix on the fixed Dev / Lockbox split
# - coarse benchmarking on **Dev only**
# - the frozen tuned random-forest model used for the manuscript-level SHAP analysis
# - OOF-style Dev evaluation
# - SHAP global patterns and dependence structure on **Dev only**
# - final held-out evaluation on **Lockbox only**

# %% [markdown]
# **Dataset profile used by the public module**
#
# - Full Stage-A activity table: **578 samples**
# - Fixed split: **491 Dev** and **87 Lockbox**
# - Frozen feature set: **24 descriptors**
# - Public tuned model: **RandomForest_StageA_tuned_bestk24.joblib**

# %% [markdown]
# ## 1. Coarse benchmarking on Dev
#
# The original Stage-A notebook identifies the following Top-3 coarse models from the Dev split:
#
# | Rank | Model | Mean RMSE across CV | Mean R² across CV |
# |---|---|---:|---:|
# | 1 | RandomForest | 0.1401 | 0.9491 |
# | 2 | Bagging | 0.1403 | 0.9490 |
# | 3 | GBDT | 0.1410 | 0.9479 |

# %% [markdown]
# ### Stage-A activity — R² heatmap across CV

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: Stage-A activity — R² heatmap across CV>

# %% [markdown]
# ### Stage-A activity — RMSE heatmap across CV

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: Stage-A activity — RMSE heatmap across CV>

# %% [markdown]
# ## 2. Leaderboard snapshot

# %%
# Embedded table snapshot from the original notebook
# Out:
#           Model  RMSE_cv_avg  RMSE_cv_std  R2_cv_avg
# 0  RandomForest     0.140064     0.002430   0.949133
# 1       Bagging     0.140265     0.002995   0.948996
# 2          GBDT     0.140969     0.005128   0.947890
# 3    ExtraTrees     0.145150     0.003466   0.945032
# 4           XGB     0.152696     0.002956   0.939288
# 5      LightGBM     0.153802     0.006080   0.938255
# 6  DecisionTree     0.170259     0.004020   0.924370
# 7       SVR_RBF     0.172830     0.006115   0.921766
# 8      AdaBoost     0.189003     0.008030   0.904477
# 9           KNN     0.230897     0.001549   0.859629
# ✓ Saved: C:\Users\Administrator\ML\ML\ML\ML-Activity-Regression\artifacts\reports\reg_stageA_leaderboard.csv

# %% [markdown]
# ## 3. Frozen tuned model: performance summary
#
# The frozen tuned model used in this public module is:
#
# - **RandomForest_StageA_tuned_bestk24.joblib**
#
# The public runnable notebook reproduces:
#
# - OOF evaluation on **Dev only**
# - SHAP analysis on **Dev only**
# - final held-out evaluation on **Lockbox only**

# %% [markdown]
# ### Tuned-model summary bars

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: Tuned-model summary bars>

# %% [markdown]
# ### Tuned-model summary bars (second panel)

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: Tuned-model summary bars (second panel)>

# %% [markdown]
# ### RandomForest dependence grid (Top-6)

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: RandomForest dependence grid (Top-6)>

# %% [markdown]
# ### SHAP consensus bar

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: SHAP consensus bar>

# %% [markdown]
# ### Lockbox PCA projection

# %%
# Embedded output from the original Stage-A activity notebook
# Out:
# <Embedded figure: Lockbox PCA projection>

# %% [markdown]
# ## 4. Evaluation snapshot

# %%
# Embedded metric summary from the original Stage-A activity notebook
# Out:
# [Eval] RandomForest
#
# [Eval] Bagging
#
# [Eval] GBDT
#
# Metric                    MAE      R2    RMSE
# Model        Set
# Bagging      Hold-out  0.0948  0.9487  0.1462
#              Lockbox   0.0951  0.9512  0.1432
#              OOF       0.0922  0.9533  0.1357
# GBDT         Hold-out  0.0961  0.9508  0.1433
#              Lockbox   0.1188  0.9291  0.1727
#              OOF       0.0987  0.9484  0.1425
# RandomForest Hold-out  0.0924  0.9525  0.1408
#              Lockbox   0.0949  0.9486  0.1470
#              OOF       0.0932  0.9524  0.1370
