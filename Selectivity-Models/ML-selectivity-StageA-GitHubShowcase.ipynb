# %% [markdown]
# # Stage-A Selectivity Classification Public Module — GitHub Showcase
#
# This notebook is a display-oriented public companion for the **Stage-A selectivity classification model**.
#
# It is designed for direct GitHub preview and highlights the main public-facing components:
#
# - the full **200-sample selectivity table**
# - the fixed **Dev / Lockbox** split
# - coarse benchmarking on **Dev only**
# - OOF validation of the frozen tuned model on **Dev only**
# - SHAP-based feature-importance visualization
# - final held-out evaluation on **Lockbox only**
#
# The frozen model used by this public module is:
#
# - `RandomForest_TUNED_ROC.joblib`
#
# The fixed final feature set contains **27 descriptors**, and all public tables use **`MOFID`** as the sample identifier.

# %% [markdown]
# ## Public summary
#
# - Total samples: **200**
# - Dev samples: **170**
# - Lockbox samples: **30**
# - Final Stage-A features: **27**
# - Coarse-model Top-3: **SVC**, **RandomForest**, **Logistic**
# - Frozen tuned public model: **RandomForest_TUNED_ROC.joblib**
# - Public threshold for class-1 decision: **0.87**
# - Positive class: **1**
# - Negative class: **0**

# %% [markdown]
# ## Coarse benchmarking on Dev

# %%
# Embedded figure from the original Stage-A selectivity notebook
# Out:
# <Figure: Embedded figure from the original Stage-A selectivity notebook>
# Representative coarse-benchmarking visualization from the original notebook.

# %% [markdown]
# ## OOF validation of the tuned model on Dev

# %%
# Representative OOF validation figure
# Out:
# <Figure: Representative OOF validation figure>
# Representative OOF figure from the original notebook.

# %% [markdown]
# ## SHAP feature-importance analysis

# %%
# Representative SHAP summary figure
# Out:
# <Figure: Representative SHAP summary figure>
# Representative SHAP global-importance figure from the original notebook.

# %%
# Representative SHAP dependence figure
# Out:
# <Figure: Representative SHAP dependence figure>
# Representative SHAP dependence visualization from the original notebook.

# %% [markdown]
# ## Final held-out evaluation on Lockbox

# %%
# Representative Lockbox evaluation figure
# Out:
# <Figure: Representative Lockbox evaluation figure>
# Representative Lockbox evaluation figure from the original notebook.

# %%
# Representative Dev-vs-Lockbox covariate-shift figure
# Out:
# <Figure: Representative Dev-vs-Lockbox covariate-shift figure>
# Representative covariate-shift figure from the original notebook.

# %% [markdown]
# ## Notes
#
# This showcase notebook is intended for direct online preview.
#
# A fully runnable public notebook is provided separately as:
#
# - `ML-selectivity-StageA-PublicModule-v2.ipynb`
#
# That notebook expects the following public files to be present:
#
# - `data/selectivity_stageA_200_best27.csv`
# - `data/selectivity_stageA_split.csv`
# - `models/RandomForest_TUNED_ROC.joblib`
# - `models/selectivity_features.json`
# - `models/selectivity_tuned_meta.json`
